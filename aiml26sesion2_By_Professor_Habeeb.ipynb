# %% [markdown]
# <a href="https://colab.research.google.com/github/nkatara/iiit-ai-ml/blob/main/aiml26sesion2_By_Professor_Habeeb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
img = np.zeros((200,200,3),dtype="uint8")

# %%
img[:,:,0] = 0
img[:,:,1]=220
img[:,:,2] = 255

# %%
import imageio as io
io.imwrite("sample.jpg",img)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()
